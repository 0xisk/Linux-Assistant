# %%
desires = ['i want to', 'i need to', 'i wish to', 'i demand to', 'i long to']

# %%
volumeup_synonyms = ['volumeup', 'volume up', 'increase', 'boost', 'inflate', 'escalate',
                    'raise', 'rise', 'double', 'maximize', 'pulse']

# %%
sentences = ['volume', 'speaker', 'sound', 'tone']

# %%
count = 0
for x in volumeup_synonyms:
    for y in sentences:
        print(x + ' ' + y + ', amixer -D pulse sset Master 50%+')
        count += 1
print(count)
# Out:
# volumeup volume, amixer -D pulse sset Master 50%+
# volumeup speaker, amixer -D pulse sset Master 50%+
# volumeup sound, amixer -D pulse sset Master 50%+
# volumeup tone, amixer -D pulse sset Master 50%+
# volume up volume, amixer -D pulse sset Master 50%+
# volume up speaker, amixer -D pulse sset Master 50%+
# volume up sound, amixer -D pulse sset Master 50%+
# volume up tone, amixer -D pulse sset Master 50%+
# increase volume, amixer -D pulse sset Master 50%+
# increase speaker, amixer -D pulse sset Master 50%+
# increase sound, amixer -D pulse sset Master 50%+
# increase tone, amixer -D pulse sset Master 50%+
# boost volume, amixer -D pulse sset Master 50%+
# boost speaker, amixer -D pulse sset Master 50%+
# boost sound, amixer -D pulse sset Master 50%+
# boost tone, amixer -D pulse sset Master 50%+
# inflate volume, amixer -D pulse sset Master 50%+
# inflate speaker, amixer -D pulse sset Master 50%+
# inflate sound, amixer -D pulse sset Master 50%+
# inflate tone, amixer -D pulse sset Master 50%+
# escalate volume, amixer -D pulse sset Master 50%+
# escalate speaker, amixer -D pulse sset Master 50%+
# escalate sound, amixer -D pulse sset Master 50%+
# escalate tone, amixer -D pulse sset Master 50%+
# raise volume, amixer -D pulse sset Master 50%+
# raise speaker, amixer -D pulse sset Master 50%+
# raise sound, amixer -D pulse sset Master 50%+
# raise tone, amixer -D pulse sset Master 50%+
# rise volume, amixer -D pulse sset Master 50%+
# rise speaker, amixer -D pulse sset Master 50%+
# rise sound, amixer -D pulse sset Master 50%+
# rise tone, amixer -D pulse sset Master 50%+
# double volume, amixer -D pulse sset Master 50%+
# double speaker, amixer -D pulse sset Master 50%+
# double sound, amixer -D pulse sset Master 50%+
# double tone, amixer -D pulse sset Master 50%+
# maximize volume, amixer -D pulse sset Master 50%+
# maximize speaker, amixer -D pulse sset Master 50%+
# maximize sound, amixer -D pulse sset Master 50%+
# maximize tone, amixer -D pulse sset Master 50%+
# pulse volume, amixer -D pulse sset Master 50%+
# pulse speaker, amixer -D pulse sset Master 50%+
# pulse sound, amixer -D pulse sset Master 50%+
# pulse tone, amixer -D pulse sset Master 50%+
# 44

# %%
count = 0
for z in desires:
    for x in volumeup_synonyms:
        for y in sentences:
            print(z + ' ' + x + ' ' + y + ', amixer -D pulse sset Master 50%+')
            count += 1
print(count)
# Out:
# i want to volumeup volume, amixer -D pulse sset Master 50%+
# i want to volumeup speaker, amixer -D pulse sset Master 50%+
# i want to volumeup sound, amixer -D pulse sset Master 50%+
# i want to volumeup tone, amixer -D pulse sset Master 50%+
# i want to volume up volume, amixer -D pulse sset Master 50%+
# i want to volume up speaker, amixer -D pulse sset Master 50%+
# i want to volume up sound, amixer -D pulse sset Master 50%+
# i want to volume up tone, amixer -D pulse sset Master 50%+
# i want to increase volume, amixer -D pulse sset Master 50%+
# i want to increase speaker, amixer -D pulse sset Master 50%+
# i want to increase sound, amixer -D pulse sset Master 50%+
# i want to increase tone, amixer -D pulse sset Master 50%+
# i want to boost volume, amixer -D pulse sset Master 50%+
# i want to boost speaker, amixer -D pulse sset Master 50%+
# i want to boost sound, amixer -D pulse sset Master 50%+
# i want to boost tone, amixer -D pulse sset Master 50%+
# i want to inflate volume, amixer -D pulse sset Master 50%+
# i want to inflate speaker, amixer -D pulse sset Master 50%+
# i want to inflate sound, amixer -D pulse sset Master 50%+
# i want to inflate tone, amixer -D pulse sset Master 50%+
# i want to escalate volume, amixer -D pulse sset Master 50%+
# i want to escalate speaker, amixer -D pulse sset Master 50%+
# i want to escalate sound, amixer -D pulse sset Master 50%+
# i want to escalate tone, amixer -D pulse sset Master 50%+
# i want to raise volume, amixer -D pulse sset Master 50%+
# i want to raise speaker, amixer -D pulse sset Master 50%+
# i want to raise sound, amixer -D pulse sset Master 50%+
# i want to raise tone, amixer -D pulse sset Master 50%+
# i want to rise volume, amixer -D pulse sset Master 50%+
# i want to rise speaker, amixer -D pulse sset Master 50%+
# i want to rise sound, amixer -D pulse sset Master 50%+
# i want to rise tone, amixer -D pulse sset Master 50%+
# i want to double volume, amixer -D pulse sset Master 50%+
# i want to double speaker, amixer -D pulse sset Master 50%+
# i want to double sound, amixer -D pulse sset Master 50%+
# i want to double tone, amixer -D pulse sset Master 50%+
# i want to maximize volume, amixer -D pulse sset Master 50%+
# i want to maximize speaker, amixer -D pulse sset Master 50%+
# i want to maximize sound, amixer -D pulse sset Master 50%+
# i want to maximize tone, amixer -D pulse sset Master 50%+
# i want to pulse volume, amixer -D pulse sset Master 50%+
# i want to pulse speaker, amixer -D pulse sset Master 50%+
# i want to pulse sound, amixer -D pulse sset Master 50%+
# i want to pulse tone, amixer -D pulse sset Master 50%+
# i need to volumeup volume, amixer -D pulse sset Master 50%+
# i need to volumeup speaker, amixer -D pulse sset Master 50%+
# i need to volumeup sound, amixer -D pulse sset Master 50%+
# i need to volumeup tone, amixer -D pulse sset Master 50%+
# i need to volume up volume, amixer -D pulse sset Master 50%+
# i need to volume up speaker, amixer -D pulse sset Master 50%+
# i need to volume up sound, amixer -D pulse sset Master 50%+
# i need to volume up tone, amixer -D pulse sset Master 50%+
# i need to increase volume, amixer -D pulse sset Master 50%+
# i need to increase speaker, amixer -D pulse sset Master 50%+
# i need to increase sound, amixer -D pulse sset Master 50%+
# i need to increase tone, amixer -D pulse sset Master 50%+
# i need to boost volume, amixer -D pulse sset Master 50%+
# i need to boost speaker, amixer -D pulse sset Master 50%+
# i need to boost sound, amixer -D pulse sset Master 50%+
# i need to boost tone, amixer -D pulse sset Master 50%+
# i need to inflate volume, amixer -D pulse sset Master 50%+
# i need to inflate speaker, amixer -D pulse sset Master 50%+
# i need to inflate sound, amixer -D pulse sset Master 50%+
# i need to inflate tone, amixer -D pulse sset Master 50%+
# i need to escalate volume, amixer -D pulse sset Master 50%+
# i need to escalate speaker, amixer -D pulse sset Master 50%+
# i need to escalate sound, amixer -D pulse sset Master 50%+
# i need to escalate tone, amixer -D pulse sset Master 50%+
# i need to raise volume, amixer -D pulse sset Master 50%+
# i need to raise speaker, amixer -D pulse sset Master 50%+
# i need to raise sound, amixer -D pulse sset Master 50%+
# i need to raise tone, amixer -D pulse sset Master 50%+
# i need to rise volume, amixer -D pulse sset Master 50%+
# i need to rise speaker, amixer -D pulse sset Master 50%+
# i need to rise sound, amixer -D pulse sset Master 50%+
# i need to rise tone, amixer -D pulse sset Master 50%+
# i need to double volume, amixer -D pulse sset Master 50%+
# i need to double speaker, amixer -D pulse sset Master 50%+
# i need to double sound, amixer -D pulse sset Master 50%+
# i need to double tone, amixer -D pulse sset Master 50%+
# i need to maximize volume, amixer -D pulse sset Master 50%+
# i need to maximize speaker, amixer -D pulse sset Master 50%+
# i need to maximize sound, amixer -D pulse sset Master 50%+
# i need to maximize tone, amixer -D pulse sset Master 50%+
# i need to pulse volume, amixer -D pulse sset Master 50%+
# i need to pulse speaker, amixer -D pulse sset Master 50%+
# i need to pulse sound, amixer -D pulse sset Master 50%+
# i need to pulse tone, amixer -D pulse sset Master 50%+
# i wish to volumeup volume, amixer -D pulse sset Master 50%+
# i wish to volumeup speaker, amixer -D pulse sset Master 50%+
# i wish to volumeup sound, amixer -D pulse sset Master 50%+
# i wish to volumeup tone, amixer -D pulse sset Master 50%+
# i wish to volume up volume, amixer -D pulse sset Master 50%+
# i wish to volume up speaker, amixer -D pulse sset Master 50%+
# i wish to volume up sound, amixer -D pulse sset Master 50%+
# i wish to volume up tone, amixer -D pulse sset Master 50%+
# i wish to increase volume, amixer -D pulse sset Master 50%+
# i wish to increase speaker, amixer -D pulse sset Master 50%+
# i wish to increase sound, amixer -D pulse sset Master 50%+
# i wish to increase tone, amixer -D pulse sset Master 50%+
# i wish to boost volume, amixer -D pulse sset Master 50%+
# i wish to boost speaker, amixer -D pulse sset Master 50%+
# i wish to boost sound, amixer -D pulse sset Master 50%+
# i wish to boost tone, amixer -D pulse sset Master 50%+
# i wish to inflate volume, amixer -D pulse sset Master 50%+
# i wish to inflate speaker, amixer -D pulse sset Master 50%+
# i wish to inflate sound, amixer -D pulse sset Master 50%+
# i wish to inflate tone, amixer -D pulse sset Master 50%+
# i wish to escalate volume, amixer -D pulse sset Master 50%+
# i wish to escalate speaker, amixer -D pulse sset Master 50%+
# i wish to escalate sound, amixer -D pulse sset Master 50%+
# i wish to escalate tone, amixer -D pulse sset Master 50%+
# i wish to raise volume, amixer -D pulse sset Master 50%+
# i wish to raise speaker, amixer -D pulse sset Master 50%+
# i wish to raise sound, amixer -D pulse sset Master 50%+
# i wish to raise tone, amixer -D pulse sset Master 50%+
# i wish to rise volume, amixer -D pulse sset Master 50%+
# i wish to rise speaker, amixer -D pulse sset Master 50%+
# i wish to rise sound, amixer -D pulse sset Master 50%+
# i wish to rise tone, amixer -D pulse sset Master 50%+
# i wish to double volume, amixer -D pulse sset Master 50%+
# i wish to double speaker, amixer -D pulse sset Master 50%+
# i wish to double sound, amixer -D pulse sset Master 50%+
# i wish to double tone, amixer -D pulse sset Master 50%+
# i wish to maximize volume, amixer -D pulse sset Master 50%+
# i wish to maximize speaker, amixer -D pulse sset Master 50%+
# i wish to maximize sound, amixer -D pulse sset Master 50%+
# i wish to maximize tone, amixer -D pulse sset Master 50%+
# i wish to pulse volume, amixer -D pulse sset Master 50%+
# i wish to pulse speaker, amixer -D pulse sset Master 50%+
# i wish to pulse sound, amixer -D pulse sset Master 50%+
# i wish to pulse tone, amixer -D pulse sset Master 50%+
# i demand to volumeup volume, amixer -D pulse sset Master 50%+
# i demand to volumeup speaker, amixer -D pulse sset Master 50%+
# i demand to volumeup sound, amixer -D pulse sset Master 50%+
# i demand to volumeup tone, amixer -D pulse sset Master 50%+
# i demand to volume up volume, amixer -D pulse sset Master 50%+
# i demand to volume up speaker, amixer -D pulse sset Master 50%+
# i demand to volume up sound, amixer -D pulse sset Master 50%+
# i demand to volume up tone, amixer -D pulse sset Master 50%+
# i demand to increase volume, amixer -D pulse sset Master 50%+
# i demand to increase speaker, amixer -D pulse sset Master 50%+
# i demand to increase sound, amixer -D pulse sset Master 50%+
# i demand to increase tone, amixer -D pulse sset Master 50%+
# i demand to boost volume, amixer -D pulse sset Master 50%+
# i demand to boost speaker, amixer -D pulse sset Master 50%+
# i demand to boost sound, amixer -D pulse sset Master 50%+
# i demand to boost tone, amixer -D pulse sset Master 50%+
# i demand to inflate volume, amixer -D pulse sset Master 50%+
# i demand to inflate speaker, amixer -D pulse sset Master 50%+
# i demand to inflate sound, amixer -D pulse sset Master 50%+
# i demand to inflate tone, amixer -D pulse sset Master 50%+
# i demand to escalate volume, amixer -D pulse sset Master 50%+
# i demand to escalate speaker, amixer -D pulse sset Master 50%+
# i demand to escalate sound, amixer -D pulse sset Master 50%+
# i demand to escalate tone, amixer -D pulse sset Master 50%+
# i demand to raise volume, amixer -D pulse sset Master 50%+
# i demand to raise speaker, amixer -D pulse sset Master 50%+
# i demand to raise sound, amixer -D pulse sset Master 50%+
# i demand to raise tone, amixer -D pulse sset Master 50%+
# i demand to rise volume, amixer -D pulse sset Master 50%+
# i demand to rise speaker, amixer -D pulse sset Master 50%+
# i demand to rise sound, amixer -D pulse sset Master 50%+
# i demand to rise tone, amixer -D pulse sset Master 50%+
# i demand to double volume, amixer -D pulse sset Master 50%+
# i demand to double speaker, amixer -D pulse sset Master 50%+
# i demand to double sound, amixer -D pulse sset Master 50%+
# i demand to double tone, amixer -D pulse sset Master 50%+
# i demand to maximize volume, amixer -D pulse sset Master 50%+
# i demand to maximize speaker, amixer -D pulse sset Master 50%+
# i demand to maximize sound, amixer -D pulse sset Master 50%+
# i demand to maximize tone, amixer -D pulse sset Master 50%+
# i demand to pulse volume, amixer -D pulse sset Master 50%+
# i demand to pulse speaker, amixer -D pulse sset Master 50%+
# i demand to pulse sound, amixer -D pulse sset Master 50%+
# i demand to pulse tone, amixer -D pulse sset Master 50%+
# i long to volumeup volume, amixer -D pulse sset Master 50%+
# i long to volumeup speaker, amixer -D pulse sset Master 50%+
# i long to volumeup sound, amixer -D pulse sset Master 50%+
# i long to volumeup tone, amixer -D pulse sset Master 50%+
# i long to volume up volume, amixer -D pulse sset Master 50%+
# i long to volume up speaker, amixer -D pulse sset Master 50%+
# i long to volume up sound, amixer -D pulse sset Master 50%+
# i long to volume up tone, amixer -D pulse sset Master 50%+
# i long to increase volume, amixer -D pulse sset Master 50%+
# i long to increase speaker, amixer -D pulse sset Master 50%+
# i long to increase sound, amixer -D pulse sset Master 50%+
# i long to increase tone, amixer -D pulse sset Master 50%+
# i long to boost volume, amixer -D pulse sset Master 50%+
# i long to boost speaker, amixer -D pulse sset Master 50%+
# i long to boost sound, amixer -D pulse sset Master 50%+
# i long to boost tone, amixer -D pulse sset Master 50%+
# i long to inflate volume, amixer -D pulse sset Master 50%+
# i long to inflate speaker, amixer -D pulse sset Master 50%+
# i long to inflate sound, amixer -D pulse sset Master 50%+
# i long to inflate tone, amixer -D pulse sset Master 50%+
# i long to escalate volume, amixer -D pulse sset Master 50%+
# i long to escalate speaker, amixer -D pulse sset Master 50%+
# i long to escalate sound, amixer -D pulse sset Master 50%+
# i long to escalate tone, amixer -D pulse sset Master 50%+
# i long to raise volume, amixer -D pulse sset Master 50%+
# i long to raise speaker, amixer -D pulse sset Master 50%+
# i long to raise sound, amixer -D pulse sset Master 50%+
# i long to raise tone, amixer -D pulse sset Master 50%+
# i long to rise volume, amixer -D pulse sset Master 50%+
# i long to rise speaker, amixer -D pulse sset Master 50%+
# i long to rise sound, amixer -D pulse sset Master 50%+
# i long to rise tone, amixer -D pulse sset Master 50%+
# i long to double volume, amixer -D pulse sset Master 50%+
# i long to double speaker, amixer -D pulse sset Master 50%+
# i long to double sound, amixer -D pulse sset Master 50%+
# i long to double tone, amixer -D pulse sset Master 50%+
# i long to maximize volume, amixer -D pulse sset Master 50%+
# i long to maximize speaker, amixer -D pulse sset Master 50%+
# i long to maximize sound, amixer -D pulse sset Master 50%+
# i long to maximize tone, amixer -D pulse sset Master 50%+
# i long to pulse volume, amixer -D pulse sset Master 50%+
# i long to pulse speaker, amixer -D pulse sset Master 50%+
# i long to pulse sound, amixer -D pulse sset Master 50%+
# i long to pulse tone, amixer -D pulse sset Master 50%+
# 220
