# %%
desires = ['i want to', 'i need to', 'i wish to', 'i demand to', 'i long to']

# %%
volumendown_synonyms = ['volumedown', 'volume down', 'decrease', 'down', 'discount', 'drop',
                       'downgrade']

# %%
sentences = ['volume', 'speaker', 'sound', 'tone']

# %%
count = 0
for x in volumendown_synonyms:
    for y in sentences:
        print(x + ' ' + y + ', amixer -D pulse sset Master 50%-')
        count += 1
print(count)
# Out:
# volumedown volume, amixer -D pulse sset Master 50%-
# volumedown speaker, amixer -D pulse sset Master 50%-
# volumedown sound, amixer -D pulse sset Master 50%-
# volumedown tone, amixer -D pulse sset Master 50%-
# volume down volume, amixer -D pulse sset Master 50%-
# volume down speaker, amixer -D pulse sset Master 50%-
# volume down sound, amixer -D pulse sset Master 50%-
# volume down tone, amixer -D pulse sset Master 50%-
# decrease volume, amixer -D pulse sset Master 50%-
# decrease speaker, amixer -D pulse sset Master 50%-
# decrease sound, amixer -D pulse sset Master 50%-
# decrease tone, amixer -D pulse sset Master 50%-
# down volume, amixer -D pulse sset Master 50%-
# down speaker, amixer -D pulse sset Master 50%-
# down sound, amixer -D pulse sset Master 50%-
# down tone, amixer -D pulse sset Master 50%-
# discount volume, amixer -D pulse sset Master 50%-
# discount speaker, amixer -D pulse sset Master 50%-
# discount sound, amixer -D pulse sset Master 50%-
# discount tone, amixer -D pulse sset Master 50%-
# drop volume, amixer -D pulse sset Master 50%-
# drop speaker, amixer -D pulse sset Master 50%-
# drop sound, amixer -D pulse sset Master 50%-
# drop tone, amixer -D pulse sset Master 50%-
# downgrade volume, amixer -D pulse sset Master 50%-
# downgrade speaker, amixer -D pulse sset Master 50%-
# downgrade sound, amixer -D pulse sset Master 50%-
# downgrade tone, amixer -D pulse sset Master 50%-
# 28

# %%
count = 0
for z in desires:
    for x in volumendown_synonyms:
        for y in sentences:
            print(z + ' ' + x + ' ' + y + ', amixer -D pulse sset Master 50%-')
            count += 1
print(count)
# Out:
# i want to volumedown volume, amixer -D pulse sset Master 50%-
# i want to volumedown speaker, amixer -D pulse sset Master 50%-
# i want to volumedown sound, amixer -D pulse sset Master 50%-
# i want to volumedown tone, amixer -D pulse sset Master 50%-
# i want to volume down volume, amixer -D pulse sset Master 50%-
# i want to volume down speaker, amixer -D pulse sset Master 50%-
# i want to volume down sound, amixer -D pulse sset Master 50%-
# i want to volume down tone, amixer -D pulse sset Master 50%-
# i want to decrease volume, amixer -D pulse sset Master 50%-
# i want to decrease speaker, amixer -D pulse sset Master 50%-
# i want to decrease sound, amixer -D pulse sset Master 50%-
# i want to decrease tone, amixer -D pulse sset Master 50%-
# i want to down volume, amixer -D pulse sset Master 50%-
# i want to down speaker, amixer -D pulse sset Master 50%-
# i want to down sound, amixer -D pulse sset Master 50%-
# i want to down tone, amixer -D pulse sset Master 50%-
# i want to discount volume, amixer -D pulse sset Master 50%-
# i want to discount speaker, amixer -D pulse sset Master 50%-
# i want to discount sound, amixer -D pulse sset Master 50%-
# i want to discount tone, amixer -D pulse sset Master 50%-
# i want to drop volume, amixer -D pulse sset Master 50%-
# i want to drop speaker, amixer -D pulse sset Master 50%-
# i want to drop sound, amixer -D pulse sset Master 50%-
# i want to drop tone, amixer -D pulse sset Master 50%-
# i want to downgrade volume, amixer -D pulse sset Master 50%-
# i want to downgrade speaker, amixer -D pulse sset Master 50%-
# i want to downgrade sound, amixer -D pulse sset Master 50%-
# i want to downgrade tone, amixer -D pulse sset Master 50%-
# i need to volumedown volume, amixer -D pulse sset Master 50%-
# i need to volumedown speaker, amixer -D pulse sset Master 50%-
# i need to volumedown sound, amixer -D pulse sset Master 50%-
# i need to volumedown tone, amixer -D pulse sset Master 50%-
# i need to volume down volume, amixer -D pulse sset Master 50%-
# i need to volume down speaker, amixer -D pulse sset Master 50%-
# i need to volume down sound, amixer -D pulse sset Master 50%-
# i need to volume down tone, amixer -D pulse sset Master 50%-
# i need to decrease volume, amixer -D pulse sset Master 50%-
# i need to decrease speaker, amixer -D pulse sset Master 50%-
# i need to decrease sound, amixer -D pulse sset Master 50%-
# i need to decrease tone, amixer -D pulse sset Master 50%-
# i need to down volume, amixer -D pulse sset Master 50%-
# i need to down speaker, amixer -D pulse sset Master 50%-
# i need to down sound, amixer -D pulse sset Master 50%-
# i need to down tone, amixer -D pulse sset Master 50%-
# i need to discount volume, amixer -D pulse sset Master 50%-
# i need to discount speaker, amixer -D pulse sset Master 50%-
# i need to discount sound, amixer -D pulse sset Master 50%-
# i need to discount tone, amixer -D pulse sset Master 50%-
# i need to drop volume, amixer -D pulse sset Master 50%-
# i need to drop speaker, amixer -D pulse sset Master 50%-
# i need to drop sound, amixer -D pulse sset Master 50%-
# i need to drop tone, amixer -D pulse sset Master 50%-
# i need to downgrade volume, amixer -D pulse sset Master 50%-
# i need to downgrade speaker, amixer -D pulse sset Master 50%-
# i need to downgrade sound, amixer -D pulse sset Master 50%-
# i need to downgrade tone, amixer -D pulse sset Master 50%-
# i wish to volumedown volume, amixer -D pulse sset Master 50%-
# i wish to volumedown speaker, amixer -D pulse sset Master 50%-
# i wish to volumedown sound, amixer -D pulse sset Master 50%-
# i wish to volumedown tone, amixer -D pulse sset Master 50%-
# i wish to volume down volume, amixer -D pulse sset Master 50%-
# i wish to volume down speaker, amixer -D pulse sset Master 50%-
# i wish to volume down sound, amixer -D pulse sset Master 50%-
# i wish to volume down tone, amixer -D pulse sset Master 50%-
# i wish to decrease volume, amixer -D pulse sset Master 50%-
# i wish to decrease speaker, amixer -D pulse sset Master 50%-
# i wish to decrease sound, amixer -D pulse sset Master 50%-
# i wish to decrease tone, amixer -D pulse sset Master 50%-
# i wish to down volume, amixer -D pulse sset Master 50%-
# i wish to down speaker, amixer -D pulse sset Master 50%-
# i wish to down sound, amixer -D pulse sset Master 50%-
# i wish to down tone, amixer -D pulse sset Master 50%-
# i wish to discount volume, amixer -D pulse sset Master 50%-
# i wish to discount speaker, amixer -D pulse sset Master 50%-
# i wish to discount sound, amixer -D pulse sset Master 50%-
# i wish to discount tone, amixer -D pulse sset Master 50%-
# i wish to drop volume, amixer -D pulse sset Master 50%-
# i wish to drop speaker, amixer -D pulse sset Master 50%-
# i wish to drop sound, amixer -D pulse sset Master 50%-
# i wish to drop tone, amixer -D pulse sset Master 50%-
# i wish to downgrade volume, amixer -D pulse sset Master 50%-
# i wish to downgrade speaker, amixer -D pulse sset Master 50%-
# i wish to downgrade sound, amixer -D pulse sset Master 50%-
# i wish to downgrade tone, amixer -D pulse sset Master 50%-
# i demand to volumedown volume, amixer -D pulse sset Master 50%-
# i demand to volumedown speaker, amixer -D pulse sset Master 50%-
# i demand to volumedown sound, amixer -D pulse sset Master 50%-
# i demand to volumedown tone, amixer -D pulse sset Master 50%-
# i demand to volume down volume, amixer -D pulse sset Master 50%-
# i demand to volume down speaker, amixer -D pulse sset Master 50%-
# i demand to volume down sound, amixer -D pulse sset Master 50%-
# i demand to volume down tone, amixer -D pulse sset Master 50%-
# i demand to decrease volume, amixer -D pulse sset Master 50%-
# i demand to decrease speaker, amixer -D pulse sset Master 50%-
# i demand to decrease sound, amixer -D pulse sset Master 50%-
# i demand to decrease tone, amixer -D pulse sset Master 50%-
# i demand to down volume, amixer -D pulse sset Master 50%-
# i demand to down speaker, amixer -D pulse sset Master 50%-
# i demand to down sound, amixer -D pulse sset Master 50%-
# i demand to down tone, amixer -D pulse sset Master 50%-
# i demand to discount volume, amixer -D pulse sset Master 50%-
# i demand to discount speaker, amixer -D pulse sset Master 50%-
# i demand to discount sound, amixer -D pulse sset Master 50%-
# i demand to discount tone, amixer -D pulse sset Master 50%-
# i demand to drop volume, amixer -D pulse sset Master 50%-
# i demand to drop speaker, amixer -D pulse sset Master 50%-
# i demand to drop sound, amixer -D pulse sset Master 50%-
# i demand to drop tone, amixer -D pulse sset Master 50%-
# i demand to downgrade volume, amixer -D pulse sset Master 50%-
# i demand to downgrade speaker, amixer -D pulse sset Master 50%-
# i demand to downgrade sound, amixer -D pulse sset Master 50%-
# i demand to downgrade tone, amixer -D pulse sset Master 50%-
# i long to volumedown volume, amixer -D pulse sset Master 50%-
# i long to volumedown speaker, amixer -D pulse sset Master 50%-
# i long to volumedown sound, amixer -D pulse sset Master 50%-
# i long to volumedown tone, amixer -D pulse sset Master 50%-
# i long to volume down volume, amixer -D pulse sset Master 50%-
# i long to volume down speaker, amixer -D pulse sset Master 50%-
# i long to volume down sound, amixer -D pulse sset Master 50%-
# i long to volume down tone, amixer -D pulse sset Master 50%-
# i long to decrease volume, amixer -D pulse sset Master 50%-
# i long to decrease speaker, amixer -D pulse sset Master 50%-
# i long to decrease sound, amixer -D pulse sset Master 50%-
# i long to decrease tone, amixer -D pulse sset Master 50%-
# i long to down volume, amixer -D pulse sset Master 50%-
# i long to down speaker, amixer -D pulse sset Master 50%-
# i long to down sound, amixer -D pulse sset Master 50%-
# i long to down tone, amixer -D pulse sset Master 50%-
# i long to discount volume, amixer -D pulse sset Master 50%-
# i long to discount speaker, amixer -D pulse sset Master 50%-
# i long to discount sound, amixer -D pulse sset Master 50%-
# i long to discount tone, amixer -D pulse sset Master 50%-
# i long to drop volume, amixer -D pulse sset Master 50%-
# i long to drop speaker, amixer -D pulse sset Master 50%-
# i long to drop sound, amixer -D pulse sset Master 50%-
# i long to drop tone, amixer -D pulse sset Master 50%-
# i long to downgrade volume, amixer -D pulse sset Master 50%-
# i long to downgrade speaker, amixer -D pulse sset Master 50%-
# i long to downgrade sound, amixer -D pulse sset Master 50%-
# i long to downgrade tone, amixer -D pulse sset Master 50%-
# 140
